# %%
#import libraries
import pandas as pd
import numpy as np
import re

# %%
#open manufacturing workers data
df1 = pd.read_csv("data/employment-by-count-US-2007-2011-raw.csv", skiprows=3)
df2 = pd.read_csv("data/employment-by-count-US-2012-2016-raw.csv", skiprows=3)
df3 = pd.read_csv("data/employment-by-count-US-2017-2021-raw.csv", skiprows=3)

# %%
#show data
df2.tail(20)
# Out:
#                                                 GeoFips         GeoName  \
# 3110                                              56031      Platte, WY
# 3111                                              56033    Sheridan, WY
# 3112                                              56035    Sublette, WY
# 3113                                              56037  Sweetwater, WY
# 3114                                              56039       Teton, WY
# 3115                                              56041       Uinta, WY
# 3116                                              56043    Washakie, WY
# 3117                                              56045      Weston, WY
# 3118                                   Legend/Footnotes             NaN
# 3119  1/ The estimates of employment for 2001-2006 a...             NaN
# 3120  * Estimates from 2008 forward separate Skagway...             NaN
# 3121  * Wade Hampton Census Area was renamed Kusilva...             NaN
# 3122  * On January 2, 2019, two new county equivalen...             NaN
# 3123  * Broomfield County, CO, was created from part...             NaN
# 3124  * Kalawao County, Hawaii is combined with Maui...             NaN
# 3125  * Shannon County, SD was renamed to Oglala Lak...             NaN
# 3126  * Virginia combination areas consist of one or...             NaN
# 3127    Metropolitan Areas are defined (geographical...             NaN
# 3128                                (NA) Not available.             NaN
# 3129    Last updated: November 16, 2022-- new statis...             NaN
#
#        2012   2013   2014   2015   2016
# 3110   4132   4158   4183   4340   4129
# 3111  15340  15579  15986  16179  16337
# 3112   6502   6052   5859   5323   4750
# 3113  25524  25265  24932  24087  22722
# 3114  24758  26043  27224  27977  29251
# 3115   9992   9587   9698   9494   9065
# 3116   4298   4221   4185   4162   4004
# 3117   2759   2751   2931   2945   2887
# 3118    NaN    NaN    NaN    NaN    NaN
# 3119    NaN    NaN    NaN    NaN    NaN
# 3120    NaN    NaN    NaN    NaN    NaN
# 3121    NaN    NaN    NaN    NaN    NaN
# 3122    NaN    NaN    NaN    NaN    NaN
# 3123    NaN    NaN    NaN    NaN    NaN
# 3124    NaN    NaN    NaN    NaN    NaN
# 3125    NaN    NaN    NaN    NaN    NaN
# 3126    NaN    NaN    NaN    NaN    NaN
# 3127    NaN    NaN    NaN    NaN    NaN
# 3128    NaN    NaN    NaN    NaN    NaN
# 3129    NaN    NaN    NaN    NaN    NaN

# %%
#drop final rows
df1 = df1.drop([3118,3119,3120,3121,3122,3123,3124,3125,3126,3127,3128,3129])
df2 = df2.drop([3118,3119,3120,3121,3122,3123,3124,3125,3126,3127,3128,3129])
df3 = df3.drop([3118,3119,3120,3121,3122,3123,3124,3125,3126,3127,3128,3129])
df3
# Out:
#      GeoFips         GeoName   2017    2018    2019    2020    2021
# 0      01001     Autauga, AL  14855   15253   15418   15747   16316
# 1      01003     Baldwin, AL  99886  103796  104931  105026  109485
# 2      01005     Barbour, AL   9350    9228    9551    9375    9247
# 3      01007        Bibb, AL   4823    4952    5369    5489    5609
# 4      01009      Blount, AL  11750   12298   12377   12297   12530
# ...      ...             ...    ...     ...     ...     ...     ...
# 3113   56037  Sweetwater, WY  22885   22989   22851   20824   20656
# 3114   56039       Teton, WY  29872   30791   31100   30203   32664
# 3115   56041       Uinta, WY   9010    9159    9140    8854    8963
# 3116   56043    Washakie, WY   4036    4026    3860    3881    4010
# 3117   56045      Weston, WY   2792    2737    2751    2771    2791
#
# [3118 rows x 7 columns]

# %%
#untidy data
df1_melted = pd.melt(df1, id_vars=["GeoFips","GeoName"]).copy()
df2_melted = pd.melt(df1, id_vars=["GeoFips","GeoName"]).copy()
df3_melted = pd.melt(df1, id_vars=["GeoFips","GeoName"]).copy()

# %%
#concat data
df = pd.concat([df1_melted,df2_melted,df3_melted], axis = 0)
df
# Out:
#       GeoFips         GeoName variable  value
# 0       01001     Autauga, AL     2007  14956
# 1       01003     Baldwin, AL     2007  81452
# 2       01005     Barbour, AL     2007  11323
# 3       01007        Bibb, AL     2007   4885
# 4       01009      Blount, AL     2007  11974
# ...       ...             ...      ...    ...
# 15585   56037  Sweetwater, WY     2011  25130
# 15586   56039       Teton, WY     2011  24023
# 15587   56041       Uinta, WY     2011   9830
# 15588   56043    Washakie, WY     2011   4372
# 15589   56045      Weston, WY     2011   2623
#
# [46770 rows x 4 columns]

# %%
df
# Out:
#       GeoFips         GeoName variable  value
# 0       01001     Autauga, AL     2007  14956
# 1       01003     Baldwin, AL     2007  81452
# 2       01005     Barbour, AL     2007  11323
# 3       01007        Bibb, AL     2007   4885
# 4       01009      Blount, AL     2007  11974
# ...       ...             ...      ...    ...
# 15585   56037  Sweetwater, WY     2011  25130
# 15586   56039       Teton, WY     2011  24023
# 15587   56041       Uinta, WY     2011   9830
# 15588   56043    Washakie, WY     2011   4372
# 15589   56045      Weston, WY     2011   2623
#
# [46770 rows x 4 columns]

# %%
df["value"] = pd.to_numeric(df["value"], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46770 entries, 0 to 15589
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GeoFips   46770 non-null  object
#  1   GeoName   46770 non-null  object
#  2   variable  46770 non-null  object
#  3   value     46686 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.8+ MB

# %%
#split columns
df["County"] = df["GeoName"].str.split(',', expand=True)[0]
df["State"] = df["GeoName"].str.split(',', expand=True)[1]

# %%
df
# Out:
#       GeoFips         GeoName variable    value      County State
# 0       01001     Autauga, AL     2007  14956.0     Autauga    AL
# 1       01003     Baldwin, AL     2007  81452.0     Baldwin    AL
# 2       01005     Barbour, AL     2007  11323.0     Barbour    AL
# 3       01007        Bibb, AL     2007   4885.0        Bibb    AL
# 4       01009      Blount, AL     2007  11974.0      Blount    AL
# ...       ...             ...      ...      ...         ...   ...
# 15585   56037  Sweetwater, WY     2011  25130.0  Sweetwater    WY
# 15586   56039       Teton, WY     2011  24023.0       Teton    WY
# 15587   56041       Uinta, WY     2011   9830.0       Uinta    WY
# 15588   56043    Washakie, WY     2011   4372.0    Washakie    WY
# 15589   56045      Weston, WY     2011   2623.0      Weston    WY
#
# [46770 rows x 6 columns]

# %%
#arrange columns
df = df.drop(["GeoFips","GeoName"], axis =1)
df.rename(columns = {"variable": "Year","value": "Jobs" }, inplace = True)
df = df[["Year", "County","State", "Jobs"]]
df
# Out:
#        Year      County State     Jobs
# 0      2007     Autauga    AL  14956.0
# 1      2007     Baldwin    AL  81452.0
# 2      2007     Barbour    AL  11323.0
# 3      2007        Bibb    AL   4885.0
# 4      2007      Blount    AL  11974.0
# ...     ...         ...   ...      ...
# 15585  2011  Sweetwater    WY  25130.0
# 15586  2011       Teton    WY  24023.0
# 15587  2011       Uinta    WY   9830.0
# 15588  2011    Washakie    WY   4372.0
# 15589  2011      Weston    WY   2623.0
#
# [46770 rows x 4 columns]

# %%
rows = df.shape[0]
rows
# Out:
# 46770

# %%
df = df.applymap(lambda x: x.rstrip() if isinstance(x, str) else x)
df = df.applymap(lambda x: x.lstrip() if isinstance(x, str) else x)

# %%
df = df.reset_index(drop=True)
df
# Out:
#        Year      County State     Jobs
# 0      2007     Autauga    AL  14956.0
# 1      2007     Baldwin    AL  81452.0
# 2      2007     Barbour    AL  11323.0
# 3      2007        Bibb    AL   4885.0
# 4      2007      Blount    AL  11974.0
# ...     ...         ...   ...      ...
# 46765  2011  Sweetwater    WY  25130.0
# 46766  2011       Teton    WY  24023.0
# 46767  2011       Uinta    WY   9830.0
# 46768  2011    Washakie    WY   4372.0
# 46769  2011      Weston    WY   2623.0
#
# [46770 rows x 4 columns]

# %%
df["State"].unique()
# Out:
# array(['AL', 'AK', 'AK*', 'AZ', 'AR', 'CA', 'CO*', 'CO', 'CT', 'DE', 'DC',
#        'FL', 'GA', 'HI', 'HI*', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA',
#        'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH',
#        'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC',
#        'SD', 'SD*', 'TN', 'TX', 'UT', 'VT', 'VA', 'VA*',
#        'Staunton + Waynesboro', 'Colonial Heights + Petersburg',
#        'Fairfax City + Falls Church', 'Manassas + Manassas Park',
#        'Buena Vista + Lexington', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
#remove characters
df= df.replace("AK*","AK")
df= df.replace("AZ*","AZ")
df= df.replace("HI*","HI")
df= df.replace("NM*","NM")
df= df.replace("SD*","SD")
df= df.replace("CO*","CO")
df= df.replace("VA*","VA")
df= df.replace("WI*","WI")
df["State"].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'Staunton + Waynesboro',
#        'Colonial Heights + Petersburg', 'Fairfax City + Falls Church',
#        'Manassas + Manassas Park', 'Buena Vista + Lexington', 'WA', 'WV',
#        'WI', 'WY'], dtype=object)

# %%
states = {'AL':'Alabama',
         'KY': 'Kentucky',
         'OH': 'Ohio',
         'AK': 'Alaska',
         'LA': 'Louisiana',
         'OK': 'Oklahoma',
         'AZ': 'Arizona',
         'ME': 'Maine',
         'OR': 'Oregon',
         'AR': 'Arkansas',
         'MD': 'Maryland',
         'PA': 'Pennsylvania',
         'AS': 'American Samoa',
         'MA': 'Massachusetts',
         'PR': 'Puerto Rico',
         'CA': 'California',
         'MI': 'Michigan',
         'RI': 'Rhode Island',
         'CO': 'Colorado',
         'MN': 'Minnesota',
         'SC': 'South Carolina',
         'CT': 'Connecticut',
         'MS': 'Mississippi',
         'SD': 'South Dakota',
         'DE': 'Delaware',
         'MO': 'Missouri',
         'TN': 'Tennessee',
         'DC': 'District of Columbia',
         'MT': 'Montana',
         'TX': 'Texas',
         'FL': 'Florida',
         'NE': 'Nebraska',
         'TT': 'Trust Territories',
         'GA': 'Georgia',
         'NV': 'Nevada',
         'UT': 'Utah',
         'GU': 'Guam',
         'NH': 'New Hampshire',
         'VT': 'Vermont',
         'HI': 'Hawaii',
         'NJ': 'New Jersey',
         'VA': 'Virginia',
         'ID': 'Idaho',
         'NM': 'New Mexico',
         'VI': 'Virgin Islands',
         'IL': 'Illinois',
         'NY': 'New York',
         'WA': 'Washington',
         'IN': 'Indiana',
         'NC': 'North Carolina',
         'WV': 'West Virginia',
         'IA': 'Iowa',
         'ND': 'North Dakota',
         'WI': 'Wisconsin',
         'KS': 'Kansas',
         'MP': 'Northern Mariana Islands',
         'WY': 'Wyoming'}

# %%
for i in states:
    df = df.replace([i],states[i])

# %%
df
# Out:
#        Year      County    State     Jobs
# 0      2007     Autauga  Alabama  14956.0
# 1      2007     Baldwin  Alabama  81452.0
# 2      2007     Barbour  Alabama  11323.0
# 3      2007        Bibb  Alabama   4885.0
# 4      2007      Blount  Alabama  11974.0
# ...     ...         ...      ...      ...
# 46765  2011  Sweetwater  Wyoming  25130.0
# 46766  2011       Teton  Wyoming  24023.0
# 46767  2011       Uinta  Wyoming   9830.0
# 46768  2011    Washakie  Wyoming   4372.0
# 46769  2011      Weston  Wyoming   2623.0
#
# [46770 rows x 4 columns]

# %%
df["State"][2][2]
# Out:
# 'a'

# %%
#flag border states
border = ["California", "Arizona", "New Mexico", "Texas"]
f = len(border)
df["Border State"] = "NA"
for k in range(rows):
    p = 0
    for l in range(f):
        if df["State"][k] == border[l]:
            p = p +1
    if p > 0:
        df["Border State"][k] = "Yes"
    else:
        df["Border State"][k] = "No"
# Out:
# <ipython-input-21-c1a28753358c>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Border State"][k] = "No"
# <ipython-input-21-c1a28753358c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Border State"][k] = "Yes"

# %%
df
# Out:
#        Year      County    State     Jobs Border State
# 0      2007     Autauga  Alabama  14956.0           No
# 1      2007     Baldwin  Alabama  81452.0           No
# 2      2007     Barbour  Alabama  11323.0           No
# 3      2007        Bibb  Alabama   4885.0           No
# 4      2007      Blount  Alabama  11974.0           No
# ...     ...         ...      ...      ...          ...
# 46765  2011  Sweetwater  Wyoming  25130.0           No
# 46766  2011       Teton  Wyoming  24023.0           No
# 46767  2011       Uinta  Wyoming   9830.0           No
# 46768  2011    Washakie  Wyoming   4372.0           No
# 46769  2011      Weston  Wyoming   2623.0           No
#
# [46770 rows x 5 columns]

# %%
df.groupby("Border State")["Border State"].agg("count")
# Out:
# Border State
# No     41370
# Yes     5400
# Name: Border State, dtype: int64

# %%
df.query("County == 'Santa Cruz'")
# Out:
#        Year      County       State      Jobs Border State
# 113    2007  Santa Cruz     Arizona   16155.0          Yes
# 234    2007  Santa Cruz  California  119091.0          Yes
# 3231   2008  Santa Cruz     Arizona   15580.0          Yes
# 3352   2008  Santa Cruz  California  116405.0          Yes
# 6349   2009  Santa Cruz     Arizona   14827.0          Yes
# 6470   2009  Santa Cruz  California  112418.0          Yes
# 9467   2010  Santa Cruz     Arizona   14812.0          Yes
# 9588   2010  Santa Cruz  California  111340.0          Yes
# 12585  2011  Santa Cruz     Arizona   15239.0          Yes
# 12706  2011  Santa Cruz  California  112777.0          Yes
# 15703  2007  Santa Cruz     Arizona   16155.0          Yes
# 15824  2007  Santa Cruz  California  119091.0          Yes
# 18821  2008  Santa Cruz     Arizona   15580.0          Yes
# 18942  2008  Santa Cruz  California  116405.0          Yes
# 21939  2009  Santa Cruz     Arizona   14827.0          Yes
# 22060  2009  Santa Cruz  California  112418.0          Yes
# 25057  2010  Santa Cruz     Arizona   14812.0          Yes
# 25178  2010  Santa Cruz  California  111340.0          Yes
# 28175  2011  Santa Cruz     Arizona   15239.0          Yes
# 28296  2011  Santa Cruz  California  112777.0          Yes
# 31293  2007  Santa Cruz     Arizona   16155.0          Yes
# 31414  2007  Santa Cruz  California  119091.0          Yes
# 34411  2008  Santa Cruz     Arizona   15580.0          Yes
# 34532  2008  Santa Cruz  California  116405.0          Yes
# 37529  2009  Santa Cruz     Arizona   14827.0          Yes
# 37650  2009  Santa Cruz  California  112418.0          Yes
# 40647  2010  Santa Cruz     Arizona   14812.0          Yes
# 40768  2010  Santa Cruz  California  111340.0          Yes
# 43765  2011  Santa Cruz     Arizona   15239.0          Yes
# 43886  2011  Santa Cruz  California  112777.0          Yes

# %%
#flag border counties
border_counties = ['San Diego', 'Imperial', 'Yuma', 'Pima', 'Santa Cruz', 'Cochise', 'Hidalgo', 'Luna' , 'Doña Ana','El Paso','Hudspeth' ,'Jeff Davis','Presidio', 'Brewster', 'Terrell' ,'Val Verde', 'Kinney' ,'Maverick', 'Webb' ,'Zapata', 'Starr' ,'Hidalgo', 'Cameron']
f = len(border_counties)
df["Border County"] = "NA"
for k in range(rows):
    p = 0
    for l in range(f):
        if df["County"][k] == border_counties[l]:
            p = p +1
    if p > 0:
        df["Border County"][k] = "Yes"
    else:
        df["Border County"][k] = "No"
# Out:
# <ipython-input-25-2e1fb85103cd>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Border County"][k] = "No"
# <ipython-input-25-2e1fb85103cd>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Border County"][k] = "Yes"

# %%
df
# Out:
#        Year      County    State     Jobs Border State Border County
# 0      2007     Autauga  Alabama  14956.0           No            No
# 1      2007     Baldwin  Alabama  81452.0           No            No
# 2      2007     Barbour  Alabama  11323.0           No            No
# 3      2007        Bibb  Alabama   4885.0           No            No
# 4      2007      Blount  Alabama  11974.0           No            No
# ...     ...         ...      ...      ...          ...           ...
# 46765  2011  Sweetwater  Wyoming  25130.0           No            No
# 46766  2011       Teton  Wyoming  24023.0           No            No
# 46767  2011       Uinta  Wyoming   9830.0           No            No
# 46768  2011    Washakie  Wyoming   4372.0           No            No
# 46769  2011      Weston  Wyoming   2623.0           No            No
#
# [46770 rows x 6 columns]

# %%
#Remove non states
df = df.query("State != 'Staunton + Waynesboro' \
                                           & State != 'Colonial Heights + Petersburg' \
                                           & State != 'Fairfax City + Falls Church' \
                                           & State != 'Manassas + Manassas Park' \
                                           & State != 'Buena Vista + Lexington'")
df["State"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df
# Out:
#        Year      County    State     Jobs Border State Border County
# 0      2007     Autauga  Alabama  14956.0           No            No
# 1      2007     Baldwin  Alabama  81452.0           No            No
# 2      2007     Barbour  Alabama  11323.0           No            No
# 3      2007        Bibb  Alabama   4885.0           No            No
# 4      2007      Blount  Alabama  11974.0           No            No
# ...     ...         ...      ...      ...          ...           ...
# 46765  2011  Sweetwater  Wyoming  25130.0           No            No
# 46766  2011       Teton  Wyoming  24023.0           No            No
# 46767  2011       Uinta  Wyoming   9830.0           No            No
# 46768  2011    Washakie  Wyoming   4372.0           No            No
# 46769  2011      Weston  Wyoming   2623.0           No            No
#
# [46695 rows x 6 columns]

# %%
df.groupby("Border State")["Border State"].agg("count")
# Out:
# Border State
# No     41295
# Yes     5400
# Name: Border State, dtype: int64

# %%
df.groupby("Border County")["Border County"].agg("count")
# Out:
# Border County
# No     46245
# Yes      450
# Name: Border County, dtype: int64

# %%
df.query("`Border County` == 'Yes'")["State"].unique()
# Out:
# array(['Arizona', 'California', 'Colorado', 'Georgia', 'Louisiana',
#        'New Mexico', 'Pennsylvania', 'Texas'], dtype=object)

# %%
df.query("`Border County` == 'Yes'")["County"].unique()
# Out:
# array(['Cochise', 'Pima', 'Santa Cruz', 'Yuma', 'Imperial', 'San Diego',
#        'El Paso', 'Jeff Davis', 'Terrell', 'Cameron', 'Doña Ana',
#        'Hidalgo', 'Luna', 'Brewster', 'Hudspeth', 'Kinney', 'Maverick',
#        'Presidio', 'Starr', 'Val Verde', 'Webb', 'Zapata'], dtype=object)

# %%
df.query("`Border County` == 'Yes'")
# Out:
#        Year      County       State      Jobs Border State Border County
# 102    2007     Cochise     Arizona   38487.0          Yes           Yes
# 111    2007        Pima     Arizona  417200.0          Yes           Yes
# 113    2007  Santa Cruz     Arizona   16155.0          Yes           Yes
# 115    2007        Yuma     Arizona   63235.0          Yes           Yes
# 203    2007    Imperial  California   53083.0          Yes           Yes
# ...     ...         ...         ...       ...          ...           ...
# 46392  2011       Starr       Texas   15582.0          Yes           Yes
# 46400  2011     Terrell       Texas     333.0          Yes           Yes
# 46411  2011   Val Verde       Texas   16418.0          Yes           Yes
# 46418  2011        Webb       Texas  103853.0          Yes           Yes
# 46431  2011      Zapata       Texas    4930.0          Yes           Yes
#
# [450 rows x 6 columns]

# %%
df.query("`Border County` == 'No'")["County"].unique()
# Out:
# array(['Autauga', 'Baldwin', 'Barbour', ..., 'Uinta', 'Washakie',
#        'Weston'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46695 entries, 0 to 46769
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           46695 non-null  object
#  1   County         46695 non-null  object
#  2   State          46695 non-null  object
#  3   Jobs           46611 non-null  float64
#  4   Border State   46695 non-null  object
#  5   Border County  46695 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.5+ MB

# %%
#Export to CSV
df.to_csv("data/jobs-by-county-US-refined.csv", index = False, encoding = "UTF8")
