# %%
#import libraries
import pandas as pd
import numpy as np
import re

# %%
#open manufacturing workers data
df1 = pd.read_csv("data/wages-by-count-US-2005-2009-raw.csv", skiprows=3)
df2 = pd.read_csv("data/wages-by-count-US-2010-2015-raw.csv", skiprows=3)
df3 = pd.read_csv("data/wages-by-count-US-2016-2021-raw.csv", skiprows=3)

# %%
#show data
df1.tail(20)

# %%
#drop final rows
df1 = df1.drop([3118,3119,3120,3121,3122,3123,3124,3125,3126,3127,3128,3129,3130])
df2 = df2.drop([3118,3119,3120,3121,3122,3123,3124,3125,3126,3127,3128,3129,3130])
df3 = df3.drop([3118,3119,3120,3121,3122,3123,3124,3125,3126,3127,3128,3129,3130])
df3
# Out:
#      GeoFips         GeoName  2016  2017  2018  2019  2020  2021
# 0      01001     Autauga, AL   319   316   372   370   494   528
# 1      01003     Baldwin, AL  2321  2411  2696  3003  3390  3767
# 2      01005     Barbour, AL   648   621   628   553   519   478
# 3      01007        Bibb, AL   (D)   (D)   (D)   291   493   513
# 4      01009      Blount, AL   (D)   (D)   (D)   (D)   (D)   (D)
# ...      ...             ...   ...   ...   ...   ...   ...   ...
# 3113   56037  Sweetwater, WY  1376  1346  1413  1467  1306  1294
# 3114   56039       Teton, WY   581   666   742   745   663   762
# 3115   56041       Uinta, WY   479   486   512   526   509   482
# 3116   56043    Washakie, WY   201   177   182   173   184   198
# 3117   56045      Weston, WY   212   225   210   201   195   166
#
# [3118 rows x 8 columns]

# %%
df = pd.concat([df1,df2,df3], axis = 0)
df
# Out:
#      GeoFips         GeoName  2005  2006  2007  2008  2009 2010 2011 2012  \
# 0      01001     Autauga, AL   352   376   377   307   283  NaN  NaN  NaN
# 1      01003     Baldwin, AL  1486  1466  1548  1466  1391  NaN  NaN  NaN
# 2      01005     Barbour, AL   807   856   874   834   705  NaN  NaN  NaN
# 3      01007        Bibb, AL   224   229   201   219   194  NaN  NaN  NaN
# 4      01009      Blount, AL   (D)   (D)   (D)   (D)   (D)  NaN  NaN  NaN
# ...      ...             ...   ...   ...   ...   ...   ...  ...  ...  ...
# 3113   56037  Sweetwater, WY   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 3114   56039       Teton, WY   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 3115   56041       Uinta, WY   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 3116   56043    Washakie, WY   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 3117   56045      Weston, WY   NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN
#
#      2013 2014 2015  2016  2017  2018  2019  2020  2021
# 0     NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...   ...  ...  ...   ...   ...   ...   ...   ...   ...
# 3113  NaN  NaN  NaN  1376  1346  1413  1467  1306  1294
# 3114  NaN  NaN  NaN   581   666   742   745   663   762
# 3115  NaN  NaN  NaN   479   486   512   526   509   482
# 3116  NaN  NaN  NaN   201   177   182   173   184   198
# 3117  NaN  NaN  NaN   212   225   210   201   195   166
#
# [9354 rows x 19 columns]

# %%
#untidy data
df_melted = pd.melt(df, id_vars=["GeoFips","GeoName"]).copy()
df_melted
# Out:
#        GeoFips         GeoName variable value
# 0        01001     Autauga, AL     2005   352
# 1        01003     Baldwin, AL     2005  1486
# 2        01005     Barbour, AL     2005   807
# 3        01007        Bibb, AL     2005   224
# 4        01009      Blount, AL     2005   (D)
# ...        ...             ...      ...   ...
# 159013   56037  Sweetwater, WY     2021  1294
# 159014   56039       Teton, WY     2021   762
# 159015   56041       Uinta, WY     2021   482
# 159016   56043    Washakie, WY     2021   198
# 159017   56045      Weston, WY     2021   166
#
# [159018 rows x 4 columns]

# %%
#split columns
df_melted["County"] = df_melted["GeoName"].str.split(',', expand=True)[0]
df_melted["State"] = df_melted["GeoName"].str.split(',', expand=True)[1]

# %%
df_melted
# Out:
#        GeoFips         GeoName variable value      County State
# 0        01001     Autauga, AL     2005   352     Autauga    AL
# 1        01003     Baldwin, AL     2005  1486     Baldwin    AL
# 2        01005     Barbour, AL     2005   807     Barbour    AL
# 3        01007        Bibb, AL     2005   224        Bibb    AL
# 4        01009      Blount, AL     2005   (D)      Blount    AL
# ...        ...             ...      ...   ...         ...   ...
# 159013   56037  Sweetwater, WY     2021  1294  Sweetwater    WY
# 159014   56039       Teton, WY     2021   762       Teton    WY
# 159015   56041       Uinta, WY     2021   482       Uinta    WY
# 159016   56043    Washakie, WY     2021   198    Washakie    WY
# 159017   56045      Weston, WY     2021   166      Weston    WY
#
# [159018 rows x 6 columns]

# %%
#arrange columns
df_melted = df_melted.drop(["GeoFips","GeoName"], axis =1)
df_melted.rename(columns = {"variable": "Year","value": "Population" }, inplace = True)
df_melted = df_melted[["Year", "County","State", "Population"]]
df_melted
# Out:
#         Year      County State Population
# 0       2005     Autauga    AL        352
# 1       2005     Baldwin    AL       1486
# 2       2005     Barbour    AL        807
# 3       2005        Bibb    AL        224
# 4       2005      Blount    AL        (D)
# ...      ...         ...   ...        ...
# 159013  2021  Sweetwater    WY       1294
# 159014  2021       Teton    WY        762
# 159015  2021       Uinta    WY        482
# 159016  2021    Washakie    WY        198
# 159017  2021      Weston    WY        166
#
# [159018 rows x 4 columns]

# %%
rows = df_melted.shape[0]
rows
# Out:
# 159018

# %%
df_melted = df_melted.applymap(lambda x: x.rstrip() if isinstance(x, str) else x)
df_melted = df_melted.applymap(lambda x: x.lstrip() if isinstance(x, str) else x)

# %%
df_melted
# Out:
#         Year      County State Population
# 0       2005     Autauga    AL        352
# 1       2005     Baldwin    AL       1486
# 2       2005     Barbour    AL        807
# 3       2005        Bibb    AL        224
# 4       2005      Blount    AL        (D)
# ...      ...         ...   ...        ...
# 159013  2021  Sweetwater    WY       1294
# 159014  2021       Teton    WY        762
# 159015  2021       Uinta    WY        482
# 159016  2021    Washakie    WY        198
# 159017  2021      Weston    WY        166
#
# [159018 rows x 4 columns]

# %%
df_melted["State"].unique()
# Out:
# array(['AL', 'AK', 'AK*', 'AZ', 'AR', 'CA', 'CO*', 'CO', 'CT', 'DE', 'DC',
#        'FL', 'GA', 'HI', 'HI*', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA',
#        'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH',
#        'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC',
#        'SD', 'SD*', 'TN', 'TX', 'UT', 'VT', 'VA', 'VA*',
#        'Staunton + Waynesboro', 'Colonial Heights + Petersburg',
#        'Fairfax City + Falls Church', 'Manassas + Manassas Park',
#        'Buena Vista + Lexington', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
#remove characters
df_melted= df_melted.replace("AK*","AK")
df_melted= df_melted.replace("AZ*","AZ")
df_melted= df_melted.replace("HI*","HI")
df_melted= df_melted.replace("NM*","NM")
df_melted= df_melted.replace("SD*","SD")
df_melted= df_melted.replace("CO*","CO")
df_melted= df_melted.replace("VA*","VA")
df_melted= df_melted.replace("WI*","WI")

df_melted["State"].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'Staunton + Waynesboro',
#        'Colonial Heights + Petersburg', 'Fairfax City + Falls Church',
#        'Manassas + Manassas Park', 'Buena Vista + Lexington', 'WA', 'WV',
#        'WI', 'WY'], dtype=object)

# %%
states = {'AL':'Alabama',
         'KY': 'Kentucky',
         'OH': 'Ohio',
         'AK': 'Alaska',
         'LA': 'Louisiana',
         'OK': 'Oklahoma',
         'AZ': 'Arizona',
         'ME': 'Maine',
         'OR': 'Oregon',
         'AR': 'Arkansas',
         'MD': 'Maryland',
         'PA': 'Pennsylvania',
         'AS': 'American Samoa',
         'MA': 'Massachusetts',
         'PR': 'Puerto Rico',
         'CA': 'California',
         'MI': 'Michigan',
         'RI': 'Rhode Island',
         'CO': 'Colorado',
         'MN': 'Minnesota',
         'SC': 'South Carolina',
         'CT': 'Connecticut',
         'MS': 'Mississippi',
         'SD': 'South Dakota',
         'DE': 'Delaware',
         'MO': 'Missouri',
         'TN': 'Tennessee',
         'DC': 'District of Columbia',
         'MT': 'Montana',
         'TX': 'Texas',
         'FL': 'Florida',
         'NE': 'Nebraska',
         'TT': 'Trust Territories',
         'GA': 'Georgia',
         'NV': 'Nevada',
         'UT': 'Utah',
         'GU': 'Guam',
         'NH': 'New Hampshire',
         'VT': 'Vermont',
         'HI': 'Hawaii',
         'NJ': 'New Jersey',
         'VA': 'Virginia',
         'ID': 'Idaho',
         'NM': 'New Mexico',
         'VI': 'Virgin Islands',
         'IL': 'Illinois',
         'NY': 'New York',
         'WA': 'Washington',
         'IN': 'Indiana',
         'NC': 'North Carolina',
         'WV': 'West Virginia',
         'IA': 'Iowa',
         'ND': 'North Dakota',
         'WI': 'Wisconsin',
         'KS': 'Kansas',
         'MP': 'Northern Mariana Islands',
         'WY': 'Wyoming'}

# %%
for i in states:
    df_melted = df_melted.replace([i],states[i])

# %%
df_melted
# Out:
#         Year      County    State Population
# 0       2005     Autauga  Alabama        352
# 1       2005     Baldwin  Alabama       1486
# 2       2005     Barbour  Alabama        807
# 3       2005        Bibb  Alabama        224
# 4       2005      Blount  Alabama        (D)
# ...      ...         ...      ...        ...
# 159013  2021  Sweetwater  Wyoming       1294
# 159014  2021       Teton  Wyoming        762
# 159015  2021       Uinta  Wyoming        482
# 159016  2021    Washakie  Wyoming        198
# 159017  2021      Weston  Wyoming        166
#
# [159018 rows x 4 columns]

# %%
#flag border states
border = ["California", "Arizona", "New Mexico", "Texas"]
f = len(border)
df_melted["Border State"] = "NA"
for k in range(rows):
    p = 0
    for l in range(f):
        if df_melted["State"][k] == border[l]:
            p = p +1
    if p > 0:
        df_melted["Border State"][k] = "Yes"
    else:
        df_melted["Border State"][k] = "No"

# %%
df_melted
# Out:
#         Year      County    State Population Border State
# 0       2005     Autauga  Alabama        352           No
# 1       2005     Baldwin  Alabama       1486           No
# 2       2005     Barbour  Alabama        807           No
# 3       2005        Bibb  Alabama        224           No
# 4       2005      Blount  Alabama        (D)           No
# ...      ...         ...      ...        ...          ...
# 159013  2021  Sweetwater  Wyoming       1294           No
# 159014  2021       Teton  Wyoming        762           No
# 159015  2021       Uinta  Wyoming        482           No
# 159016  2021    Washakie  Wyoming        198           No
# 159017  2021      Weston  Wyoming        166           No
#
# [159018 rows x 5 columns]

# %%
df_melted.groupby("Border State")["Border State"].agg("count")

# %%
df_melted.query("County == 'Santa Cruz'")

# %%
#flag border counties
border_counties = ['San Diego', 'Imperial', 'Yuma', 'Pima', 'Santa Cruz', 'Cochise', 'Hidalgo', 'Luna' , 'Doña Ana','El Paso','Hudspeth' ,'Jeff Davis','Presidio', 'Brewster', 'Terrell' ,'Val Verde', 'Kinney' ,'Maverick', 'Webb' ,'Zapata', 'Starr' ,'Hidalgo', 'Cameron']
f = len(border_counties)
df_melted["Border County"] = "NA"
for k in range(rows):
    p = 0
    for l in range(f):
        if df_melted["County"][k] == border_counties[l]:
            p = p +1
    if p > 0:
        df_melted["Border County"][k] = "Yes"
    else:
        df_melted["Border County"][k] = "No"

# %%
#Remove non states
df_melted = df_melted.query("State != 'Staunton + Waynesboro' \
                                           & State != 'Colonial Heights + Petersburg' \
                                           & State != 'Fairfax City + Falls Church' \
                                           & State != 'Manassas + Manassas Park' \
                                           & State != 'Buena Vista + Lexington'")
df_melted["State"].unique()

# %%
df_melted

# %%
df_melted.groupby("Border State")["Border State"].agg("count")

# %%
df_melted.groupby("Border County")["Border County"].agg("count")

# %%
df_melted.query("`Border County` == 'Yes'")["State"].unique()

# %%
df_melted.query("`Border County` == 'Yes'")["County"].unique()

# %%
df_melted.query("`Border County` == 'Yes'")

# %%
df_melted.query("`Border County` == 'No'")["County"].unique()

# %%
df_melted.info()

# %%
#Export to CSV
df_melted.to_csv("data/population-by-county-US-refined.csv", index = False, encoding = "UTF8")
