# %%
#import libraries
import pandas as pd
import numpy as np
import re

# %%
#open factories data
dff = pd.read_csv("data/factories-mexico-total.csv",skiprows=4)

# %%
#show data
dff
# Out:
#                                               Periodos  \
# 0                                              2007/07
# 1                                              2007/08
# 2                                              2007/09
# 3                                              2007/10
# 4                                              2007/11
# ..                                                 ...
# 172                                            2021/11
# 173                                            2021/12
# 174  Notas: a/  Corresponde  a  establecimientos  c...
# 175     Cifras Preliminares: p1/ A partir de 2016/01
# 176  Fuentes: f1/ INEGI. Estad�stica del Programa d...
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Total nacional /a /f1  \
# 0                                               5062.0
# 1                                               5082.0
# 2                                               5108.0
# 3                                               5128.0
# 4                                               5143.0
# ..                                                 ...
# 172                                             5180.0
# 173                                             5184.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Aguascalientes /a /f1  \
# 0                                                 74.0
# 1                                                 76.0
# 2                                                 76.0
# 3                                                 78.0
# 4                                                 79.0
# ..                                                 ...
# 172                                               93.0
# 173                                               93.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Baja California > Total /a /f1  \
# 0                                               1013.0
# 1                                               1011.0
# 2                                               1012.0
# 3                                               1013.0
# 4                                               1017.0
# ..                                                 ...
# 172                                              926.0
# 173                                              928.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Baja California > Ensenada /a /f1  \
# 0                                                103.0
# 1                                                102.0
# 2                                                103.0
# 3                                                104.0
# 4                                                103.0
# ..                                                 ...
# 172                                               83.0
# 173                                               84.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Baja California > Mexicali /a /f1  \
# 0                                                167.0
# 1                                                168.0
# 2                                                166.0
# 3                                                165.0
# 4                                                166.0
# ..                                                 ...
# 172                                              144.0
# 173                                              144.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Baja California > Tecate /a /f1  \
# 0                                                133.0
# 1                                                132.0
# 2                                                132.0
# 3                                                131.0
# 4                                                133.0
# ..                                                 ...
# 172                                              100.0
# 173                                              100.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Baja California > Tijuana /f1 /b  \
# 0                                                610.0
# 1                                                609.0
# 2                                                611.0
# 3                                                613.0
# 4                                                615.0
# ..                                                 ...
# 172                                              599.0
# 173                                              600.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Coahuila de Zaragoza > Total /a /f1  \
# 0                                                366.0
# 1                                                368.0
# 2                                                370.0
# 3                                                372.0
# 4                                                371.0
# ..                                                 ...
# 172                                              394.0
# 173                                              394.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Coahuila de Zaragoza > Acu�a /a /f1  \
# 0                                                 47.0
# 1                                                 46.0
# 2                                                 45.0
# 3                                                 45.0
# 4                                                 45.0
# ..                                                 ...
# 172                                               48.0
# 173                                               48.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 172  ...
# 173  ...
# 174  ...
# 175  ...
# 176  ...
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Tamaulipas > Total /a /f1  \
# 0                                                397.0
# 1                                                399.0
# 2                                                401.0
# 3                                                402.0
# 4                                                404.0
# ..                                                 ...
# 172                                              358.0
# 173                                              358.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Tamaulipas > Matamoros /a /f1  \
# 0                                                130.0
# 1                                                131.0
# 2                                                133.0
# 3                                                133.0
# 4                                                134.0
# ..                                                 ...
# 172                                              114.0
# 173                                              114.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Tamaulipas > Nuevo Laredo /a /f1  \
# 0                                                 36.0
# 1                                                 36.0
# 2                                                 36.0
# 3                                                 36.0
# 4                                                 36.0
# ..                                                 ...
# 172                                               35.0
# 173                                               35.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Tamaulipas > Reynosa /a /f1  \
# 0                                                145.0
# 1                                                146.0
# 2                                                146.0
# 3                                                147.0
# 4                                                148.0
# ..                                                 ...
# 172                                              152.0
# 173                                              152.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Tamaulipas > Otros municipios /a /f1  \
# 0                                                 86.0
# 1                                                 86.0
# 2                                                 86.0
# 3                                                 86.0
# 4                                                 86.0
# ..                                                 ...
# 172                                               57.0
# 173                                               57.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Veracruz de Ignacio de la Llave /a /f1  \
# 0                                                 57.0
# 1                                                 58.0
# 2                                                 58.0
# 3                                                 58.0
# 4                                                 58.0
# ..                                                 ...
# 172                                               57.0
# 173                                               57.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Yucat�n > Total /a /f1  \
# 0                                                 92.0
# 1                                                 92.0
# 2                                                 92.0
# 3                                                 91.0
# 4                                                 90.0
# ..                                                 ...
# 172                                               52.0
# 173                                               52.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Yucat�n > M�rida /a /f1  \
# 0                                                 53.0
# 1                                                 53.0
# 2                                                 53.0
# 3                                                 53.0
# 4                                                 52.0
# ..                                                 ...
# 172                                               25.0
# 173                                               25.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Yucat�n > Otros municipios /a /f1  \
# 0                                                 39.0
# 1                                                 39.0
# 2                                                 39.0
# 3                                                 38.0
# 4                                                 38.0
# ..                                                 ...
# 172                                               27.0
# 173                                               27.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
#      Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Otras entidades federativas /a /f1
# 0                                                307.0
# 1                                                307.0
# 2                                                306.0
# 3                                                308.0
# 4                                                309.0
# ..                                                 ...
# 172                                              263.0
# 173                                              263.0
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
#
# [177 rows x 61 columns]

# %%
#drop final rows
dff = dff.drop([174,175,176])

# %%
#untidy data
dff_melted = pd.melt(dff, id_vars=["Periodos"], var_name ="State, City", value_name ="Factories").copy()
dff_melted
# Out:
#       Periodos                                        State, City  Factories
# 0      2007/07  Manufacturas > Industria manufacturera, maquil...     5062.0
# 1      2007/08  Manufacturas > Industria manufacturera, maquil...     5082.0
# 2      2007/09  Manufacturas > Industria manufacturera, maquil...     5108.0
# 3      2007/10  Manufacturas > Industria manufacturera, maquil...     5128.0
# 4      2007/11  Manufacturas > Industria manufacturera, maquil...     5143.0
# ...        ...                                                ...        ...
# 10435  2021/08  Manufacturas > Industria manufacturera, maquil...      265.0
# 10436  2021/09  Manufacturas > Industria manufacturera, maquil...      262.0
# 10437  2021/10  Manufacturas > Industria manufacturera, maquil...      262.0
# 10438  2021/11  Manufacturas > Industria manufacturera, maquil...      263.0
# 10439  2021/12  Manufacturas > Industria manufacturera, maquil...      263.0
#
# [10440 rows x 3 columns]

# %%
rowsf = dff_melted.shape[0]
rowsf
# Out:
# 10440

# %%
dff_melted["State, City"][220]
# Out:
# 'Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n (IMMEX) > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Aguascalientes /a /f1'

# %%
#clean data (parentesis)
for i in range(rowsf):
    dff_melted["State, City"][i]= re.sub(r'\([^)]*\)', '', dff_melted["State, City"][i])
# Out:
# <ipython-input-8-6d6319264d3c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_melted["State, City"][i]= re.sub(r'\([^)]*\)', '', dff_melted["State, City"][i])

# %%
dff_melted["State, City"][220]
# Out:
# 'Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n  > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > Aguascalientes /a /f1'

# %%
#clean data (other text)
dff_clean= dff_melted.replace("Manufacturas > Industria manufacturera, maquiladora y de servicios de exportaci�n  > Por entidad federativa > Establecimientos manufactureros > N�mero de establecimientos activos seg�n entidades federativas y municipios > ","",regex=True)
dff_clean= dff_clean.replace(" /a /f1","",regex=True)
dff_clean= dff_clean.replace(">",",",regex=True)
dff_clean
# Out:
#       Periodos                  State, City  Factories
# 0      2007/07               Total nacional     5062.0
# 1      2007/08               Total nacional     5082.0
# 2      2007/09               Total nacional     5108.0
# 3      2007/10               Total nacional     5128.0
# 4      2007/11               Total nacional     5143.0
# ...        ...                          ...        ...
# 10435  2021/08  Otras entidades federativas      265.0
# 10436  2021/09  Otras entidades federativas      262.0
# 10437  2021/10  Otras entidades federativas      262.0
# 10438  2021/11  Otras entidades federativas      263.0
# 10439  2021/12  Otras entidades federativas      263.0
#
# [10440 rows x 3 columns]

# %%
#split columns
dff_clean["Month"] = dff_clean["Periodos"].str.split('/', expand=True)[1]
dff_clean["Year"] = dff_clean["Periodos"].str.split('/', expand=True)[0]
dff_clean["State"] = dff_clean["State, City"].str.split(',', expand=True)[0]
dff_clean["City"] = dff_clean["State, City"].str.split(',', expand=True)[1]
dff_clean.drop(["Periodos","State, City"], axis=1)
# Out:
#        Factories Month  Year                        State  City
# 0         5062.0    07  2007               Total nacional  None
# 1         5082.0    08  2007               Total nacional  None
# 2         5108.0    09  2007               Total nacional  None
# 3         5128.0    10  2007               Total nacional  None
# 4         5143.0    11  2007               Total nacional  None
# ...          ...   ...   ...                          ...   ...
# 10435      265.0    08  2021  Otras entidades federativas  None
# 10436      262.0    09  2021  Otras entidades federativas  None
# 10437      262.0    10  2021  Otras entidades federativas  None
# 10438      263.0    11  2021  Otras entidades federativas  None
# 10439      263.0    12  2021  Otras entidades federativas  None
#
# [10440 rows x 5 columns]

# %%
#arrange columns
dff_clean = dff_clean[["Year","Month", "State","City", "Factories"]]
dff_clean
# Out:
#        Year Month                        State  City  Factories
# 0      2007    07               Total nacional  None     5062.0
# 1      2007    08               Total nacional  None     5082.0
# 2      2007    09               Total nacional  None     5108.0
# 3      2007    10               Total nacional  None     5128.0
# 4      2007    11               Total nacional  None     5143.0
# ...     ...   ...                          ...   ...        ...
# 10435  2021    08  Otras entidades federativas  None      265.0
# 10436  2021    09  Otras entidades federativas  None      262.0
# 10437  2021    10  Otras entidades federativas  None      262.0
# 10438  2021    11  Otras entidades federativas  None      263.0
# 10439  2021    12  Otras entidades federativas  None      263.0
#
# [10440 rows x 5 columns]

# %%
dff_clean["State"].unique()
# Out:
# array(['Total nacional', 'Aguascalientes', 'Baja California ',
#        'Coahuila de Zaragoza ', 'Chihuahua ', 'Ciudad de M�xico',
#        'Durango', 'Guanajuato ', 'Jalisco ', 'M�xico ', 'Nuevo Le�n ',
#        'Puebla ', 'Quer�taro ', 'San Luis Potos� ', 'Sonora ',
#        'Tamaulipas ', 'Veracruz de Ignacio de la Llave', 'Yucat�n ',
#        'Otras entidades federativas'], dtype=object)

# %%
#clean other characters
dff_clean = dff_clean.replace("M�xico","Mexico",regex=True)
dff_clean = dff_clean.replace("Le�n","Leon",regex=True)
dff_clean = dff_clean.replace("Quer�taro","Queretaro",regex=True)
dff_clean = dff_clean.replace("Potos�","Potosi",regex=True)
dff_clean = dff_clean.replace("Yucat�n","Yucatan",regex=True)

# %%
dff_clean["State"].unique()
# Out:
# array(['Total nacional', 'Aguascalientes', 'Baja California ',
#        'Coahuila de Zaragoza ', 'Chihuahua ', 'Ciudad de Mexico',
#        'Durango', 'Guanajuato ', 'Jalisco ', 'Mexico ', 'Nuevo Leon ',
#        'Puebla ', 'Queretaro ', 'San Luis Potosi ', 'Sonora ',
#        'Tamaulipas ', 'Veracruz de Ignacio de la Llave', 'Yucatan ',
#        'Otras entidades federativas'], dtype=object)

# %%
dff_clean.sample(20)
# Out:
#        Year Month                  State                       City  Factories
# 9967   2011    08               Yucatan                      M�rida       46.0
# 5235   2008    10            Nuevo Leon                       Total      638.0
# 10129  2010    08               Yucatan            Otros municipios       34.0
# 2508   2013    07             Chihuahua                   Chihuahua       96.0
# 9210   2021    01            Tamaulipas                Nuevo Laredo       36.0
# 5929   2008    08            Nuevo Leon    San Nicol�s de los Garza       58.0
# 1917   2007    10  Coahuila de Zaragoza                     Torre�n       69.0
# 7464   2020    07             Queretaro            Otros municipios      138.0
# 4823   2017    12                Mexico         Tlalnepantla de Baz       36.0
# 5484   2015    01            Nuevo Leon                     Apodaca      186.0
# 9822   2014    01               Yucatan                       Total       71.0
# 235    2012    08         Aguascalientes                       None       81.0
# 9464   2013    03            Tamaulipas            Otros municipios       70.0
# 9835   2015    02               Yucatan                       Total       69.0
# 2995   2010    08       Ciudad de Mexico                       None      135.0
# 3351   2011    04            Guanajuato                       Total      219.0
# 676    2020    05       Baja California                    Ensenada       86.0
# 5688   2017    07            Nuevo Leon                   Guadalupe       92.0
# 4419   2013    04               Jalisco            Otros municipios      151.0
# 1397   2007    12  Coahuila de Zaragoza                       Acu�a       45.0

# %%
dff_clean["City"].unique()
# Out:
# array([None, ' Total', ' Ensenada', ' Mexicali', ' Tecate',
#        ' Tijuana /f1 /b', ' Acu�a', ' Ramos Arizpe', ' Saltillo',
#        ' Torre�n', ' Otros municipios', ' Chihuahua', ' Ju�rez', ' Leon',
#        ' Guadalajara', ' Zapopan', ' Tlalnepantla de Baz', ' Toluca',
#        ' Apodaca', ' Guadalupe', ' Monterrey',
#        ' San Nicol�s de los Garza', ' Santa Catarina', ' Puebla',
#        ' Queretaro', ' San Luis Potosi', ' Hermosillo', ' Nogales',
#        ' Matamoros', ' Nuevo Laredo', ' Reynosa', ' M�rida'], dtype=object)

# %%
#clean other characters
dff_clean = dff_clean.replace("Acu�a","Acuña",regex=True)
dff_clean = dff_clean.replace("Torre�n","Torreon",regex=True)
dff_clean = dff_clean.replace("Ju�rez","Juarez",regex=True)
dff_clean = dff_clean.replace("Nicol�s","Nicolas",regex=True)
dff_clean = dff_clean.replace("M�rida","Merida",regex=True)
dff_clean = dff_clean.replace("/f1 /b","",regex=True)

# %%
dff_clean["City"].unique()
# Out:
# array([None, ' Total', ' Ensenada', ' Mexicali', ' Tecate', ' Tijuana ',
#        ' Acuña', ' Ramos Arizpe', ' Saltillo', ' Torreon',
#        ' Otros municipios', ' Chihuahua', ' Juarez', ' Leon',
#        ' Guadalajara', ' Zapopan', ' Tlalnepantla de Baz', ' Toluca',
#        ' Apodaca', ' Guadalupe', ' Monterrey',
#        ' San Nicolas de los Garza', ' Santa Catarina', ' Puebla',
#        ' Queretaro', ' San Luis Potosi', ' Hermosillo', ' Nogales',
#        ' Matamoros', ' Nuevo Laredo', ' Reynosa', ' Merida'], dtype=object)

# %%
#remove none values
for z in range(rowsf):
    if dff_clean["City"][z] == None:
        dff_clean["City"][z] = "Total"
# Out:
# <ipython-input-20-c0f4d7c67df7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_clean["City"][z] = "Total"

# %%
#remove blank spaces at the begining and end
for a in range(rowsf):
    dff_clean["State"][a] = dff_clean["State"][a].rstrip().lstrip()
    dff_clean["City"][a] = dff_clean["City"][a].rstrip().lstrip()
# Out:
# <ipython-input-21-9687192012f2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_clean["State"][a] = dff_clean["State"][a].rstrip().lstrip()
# <ipython-input-21-9687192012f2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_clean["City"][a] = dff_clean["City"][a].rstrip().lstrip()

# %%
dff_clean.sample(20)
# Out:
#        Year Month                        State                 City  Factories
# 5674   2016    05                   Nuevo Leon            Guadalupe       90.0
# 5893   2020    02                   Nuevo Leon            Monterrey       52.0
# 4855   2020    08                       Mexico  Tlalnepantla de Baz       34.0
# 7981   2020    02              San Luis Potosi     Otros municipios       66.0
# 8029   2009    08                       Sonora                Total      253.0
# 2918   2018    09                    Chihuahua     Otros municipios       67.0
# 5590   2009    05                   Nuevo Leon            Guadalupe       82.0
# 1770   2010    01         Coahuila de Zaragoza             Saltillo       64.0
# 1707   2019    04         Coahuila de Zaragoza         Ramos Arizpe       83.0
# 8618   2015    03                       Sonora     Otros municipios       88.0
# 7241   2016    06                    Queretaro            Queretaro      103.0
# 4271   2015    06                      Jalisco              Zapopan       69.0
# 10381  2017    02  Otras entidades federativas                Total      273.0
# 9857   2016    12                      Yucatan                Total       60.0
# 6777   2021    04                       Puebla               Puebla       58.0
# 729    2010    04              Baja California             Mexicali      153.0
# 2843   2012    06                    Chihuahua     Otros municipios       60.0
# 6352   2014    11                   Nuevo Leon     Otros municipios      177.0
# 3293   2020    12                      Durango                Total       77.0
# 4073   2013    06                      Jalisco          Guadalajara       81.0

# %%
#flag border states and cities
border = ["Baja California", "Coahuila de Zaragoza", "Chihuahua", "Nuevo Leon", "Tamaulipas", "Sonora"]
f = len(border)
dff_clean["Border"] = "NA"
for k in range(rowsf):
    p = 0
    for l in range(f):
        if dff_clean["State"][k] == border[l]:
            p = p +1
    if p > 0:
        dff_clean["Border"][k] = "Yes"
    else:
        dff_clean["Border"][k] = "No"
# Out:
# <ipython-input-23-03ed1279ecd5>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_clean["Border"][k] = "No"
# <ipython-input-23-03ed1279ecd5>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff_clean["Border"][k] = "Yes"

# %%
dff_clean.sample(20)
# Out:
#       Year Month                 State                      City  Factories  \
# 1632  2013    01  Coahuila de Zaragoza              Ramos Arizpe       93.0
# 1006  2018    11       Baja California                    Tecate       98.0
# 2922  2019    01             Chihuahua          Otros municipios       67.0
# 4569  2011    04                Mexico                     Total      298.0
# 7462  2020    05             Queretaro          Otros municipios      138.0
# 6962  2007    09             Queretaro                     Total      170.0
# 4289  2016    12               Jalisco                   Zapopan       68.0
# 8183  2007    12                Sonora                Hermosillo       57.0
# 492   2019    07       Baja California                     Total      927.0
# 4406  2012    03               Jalisco          Otros municipios      147.0
# 9349  2018    02            Tamaulipas                   Reynosa      151.0
# 3209  2013    12               Durango                     Total       69.0
# 6710  2015    09                Puebla                    Puebla       67.0
# 6047  2018    06            Nuevo Leon  San Nicolas de los Garza       60.0
# 7045  2014    08             Queretaro                     Total      214.0
# 7810  2020    05       San Luis Potosi           San Luis Potosi      111.0
# 9942  2009    07               Yucatan                    Merida       48.0
# 8380  2009    11                Sonora                   Nogales       97.0
# 2222  2018    09  Coahuila de Zaragoza          Otros municipios      133.0
# 7363  2012    02             Queretaro          Otros municipios      100.0
#
#      Border
# 1632    Yes
# 1006    Yes
# 2922    Yes
# 4569     No
# 7462     No
# 6962     No
# 4289     No
# 8183    Yes
# 492     Yes
# 4406     No
# 9349    Yes
# 3209     No
# 6710     No
# 6047    Yes
# 7045     No
# 7810     No
# 9942     No
# 8380    Yes
# 2222    Yes
# 7363     No

# %%
dff_clean.groupby("Border")["Border"].agg("count")
# Out:
# Border
# No     5046
# Yes    5394
# Name: Border, dtype: int64

# %%
dff_clean.query("State == 'Baja California'")
# Out:
#       Year Month            State     City  Factories Border
# 348   2007    07  Baja California    Total     1013.0    Yes
# 349   2007    08  Baja California    Total     1011.0    Yes
# 350   2007    09  Baja California    Total     1012.0    Yes
# 351   2007    10  Baja California    Total     1013.0    Yes
# 352   2007    11  Baja California    Total     1017.0    Yes
# ...    ...   ...              ...      ...        ...    ...
# 1213  2021    08  Baja California  Tijuana      609.0    Yes
# 1214  2021    09  Baja California  Tijuana      599.0    Yes
# 1215  2021    10  Baja California  Tijuana      599.0    Yes
# 1216  2021    11  Baja California  Tijuana      599.0    Yes
# 1217  2021    12  Baja California  Tijuana      600.0    Yes
#
# [870 rows x 6 columns]

# %%
#Export to CSV
dff_clean.to_csv("data/factories-mexico-refined.csv", index = False, encoding = "UTF8")
