# %% [markdown]
# ## Comparative by state in Mexico
#
# #### We analyze how employment, wages and the number of factories in Mexico evolved between 2007 and 2021. Also between 2016 and 2021
#
# #### The border states are: Baja California, Sonora, Tamaulipas, Coahuila, Chihuahua and Nuevo Leon.

# %%
#import libraries
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
## small trick to improve our display
## Unfortunately appears not to work in Colab.
## will allow us to see dataframes side-by-side
from IPython.display import display, HTML

css = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(css))
# Out:
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %%
## run the display code here
pd.options.display.float_format = '{:,.2f}'.format

# %%
#Open Manufacturing workers data
df = pd.read_csv("data/workers-factories-wages-mexico-annual.csv")
df
# Out:
#      Year                        State Border         Jobs  Factories  \
# 0    2007               Total nacional     No 1,902,121.00   5,140.00
# 1    2008               Total nacional     No 1,738,182.00   5,254.00
# 2    2009               Total nacional     No 1,645,291.00   5,214.00
# 3    2010               Total nacional     No 1,810,482.00   5,108.00
# 4    2011               Total nacional     No 1,879,114.00   5,079.00
# ..    ...                          ...    ...          ...        ...
# 280  2017  Otras entidades federativas     No   134,260.00     266.00
# 281  2018  Otras entidades federativas     No   143,292.00     264.00
# 282  2019  Otras entidades federativas     No   142,102.00     267.00
# 283  2020  Otras entidades federativas     No   135,569.00     264.00
# 284  2021  Otras entidades federativas     No   141,853.00     263.00
#
#      Average wage
# 0       13,120.12
# 1       13,360.18
# 2       14,170.41
# 3       13,945.50
# 4       14,183.43
# ..            ...
# 280     13,080.53
# 281     12,842.36
# 282     12,634.71
# 283     14,349.70
# 284     16,852.90
#
# [285 rows x 6 columns]

# %% [markdown]
# ## Jobs

# %%
df2 = pd.pivot_table(df.query("Year == 2010 | Year == 2021") , values='Jobs', index=['State','Border'], columns='Year')
df2
# Out:
# Year                                           2010         2021
# State                           Border
# Aguascalientes                  No        37,967.00    63,036.00
# Baja California                 Yes      216,912.00   364,420.00
# Chihuahua                       Yes      245,815.00   408,068.00
# Ciudad de Mexico                No        51,311.00    21,499.00
# Coahuila de Zaragoza            Yes      165,669.00   264,349.00
# Durango                         No        25,165.00    46,152.00
# Guanajuato                      No        70,660.00   163,990.00
# Jalisco                         No       102,031.00   156,146.00
# Mexico                          No       117,900.00   138,471.00
# Nuevo Leon                      Yes      218,776.00   311,784.00
# Otras entidades federativas     No        95,741.00   141,853.00
# Puebla                          No        71,544.00    79,592.00
# Queretaro                       No        52,887.00   107,124.00
# San Luis Potosi                 No        46,141.00    90,954.00
# Sonora                          No        93,235.00   130,031.00
# Tamaulipas                      Yes      162,298.00   258,257.00
# Total nacional                  No     1,810,482.00 2,791,909.00
# Veracruz de Ignacio de la Llave No        16,303.00    21,680.00
# Yucatan                         No        20,127.00    24,503.00

# %%
df2["Jobs pct chg 2010 - 2021"] = (df2[2021] / df2[2010] - 1) * 100
df2
# Out:
# Year                                           2010         2021  \
# State                           Border
# Aguascalientes                  No        37,967.00    63,036.00
# Baja California                 Yes      216,912.00   364,420.00
# Chihuahua                       Yes      245,815.00   408,068.00
# Ciudad de Mexico                No        51,311.00    21,499.00
# Coahuila de Zaragoza            Yes      165,669.00   264,349.00
# Durango                         No        25,165.00    46,152.00
# Guanajuato                      No        70,660.00   163,990.00
# Jalisco                         No       102,031.00   156,146.00
# Mexico                          No       117,900.00   138,471.00
# Nuevo Leon                      Yes      218,776.00   311,784.00
# Otras entidades federativas     No        95,741.00   141,853.00
# Puebla                          No        71,544.00    79,592.00
# Queretaro                       No        52,887.00   107,124.00
# San Luis Potosi                 No        46,141.00    90,954.00
# Sonora                          No        93,235.00   130,031.00
# Tamaulipas                      Yes      162,298.00   258,257.00
# Total nacional                  No     1,810,482.00 2,791,909.00
# Veracruz de Ignacio de la Llave No        16,303.00    21,680.00
# Yucatan                         No        20,127.00    24,503.00
#
# Year                                    Jobs pct chg 2010 - 2021
# State                           Border
# Aguascalientes                  No                         66.03
# Baja California                 Yes                        68.00
# Chihuahua                       Yes                        66.01
# Ciudad de Mexico                No                        -58.10
# Coahuila de Zaragoza            Yes                        59.56
# Durango                         No                         83.40
# Guanajuato                      No                        132.08
# Jalisco                         No                         53.04
# Mexico                          No                         17.45
# Nuevo Leon                      Yes                        42.51
# Otras entidades federativas     No                         48.16
# Puebla                          No                         11.25
# Queretaro                       No                        102.55
# San Luis Potosi                 No                         97.12
# Sonora                          No                         39.47
# Tamaulipas                      Yes                        59.13
# Total nacional                  No                         54.21
# Veracruz de Ignacio de la Llave No                         32.98
# Yucatan                         No                         21.74

# %%
df2.sort_values(by= ["Jobs pct chg 2010 - 2021"], ascending = False)
# Out:
# Year                                           2010         2021  \
# State                           Border
# Guanajuato                      No        70,660.00   163,990.00
# Queretaro                       No        52,887.00   107,124.00
# San Luis Potosi                 No        46,141.00    90,954.00
# Durango                         No        25,165.00    46,152.00
# Baja California                 Yes      216,912.00   364,420.00
# Aguascalientes                  No        37,967.00    63,036.00
# Chihuahua                       Yes      245,815.00   408,068.00
# Coahuila de Zaragoza            Yes      165,669.00   264,349.00
# Tamaulipas                      Yes      162,298.00   258,257.00
# Total nacional                  No     1,810,482.00 2,791,909.00
# Jalisco                         No       102,031.00   156,146.00
# Otras entidades federativas     No        95,741.00   141,853.00
# Nuevo Leon                      Yes      218,776.00   311,784.00
# Sonora                          No        93,235.00   130,031.00
# Veracruz de Ignacio de la Llave No        16,303.00    21,680.00
# Yucatan                         No        20,127.00    24,503.00
# Mexico                          No       117,900.00   138,471.00
# Puebla                          No        71,544.00    79,592.00
# Ciudad de Mexico                No        51,311.00    21,499.00
#
# Year                                    Jobs pct chg 2010 - 2021
# State                           Border
# Guanajuato                      No                        132.08
# Queretaro                       No                        102.55
# San Luis Potosi                 No                         97.12
# Durango                         No                         83.40
# Baja California                 Yes                        68.00
# Aguascalientes                  No                         66.03
# Chihuahua                       Yes                        66.01
# Coahuila de Zaragoza            Yes                        59.56
# Tamaulipas                      Yes                        59.13
# Total nacional                  No                         54.21
# Jalisco                         No                         53.04
# Otras entidades federativas     No                         48.16
# Nuevo Leon                      Yes                        42.51
# Sonora                          No                         39.47
# Veracruz de Ignacio de la Llave No                         32.98
# Yucatan                         No                         21.74
# Mexico                          No                         17.45
# Puebla                          No                         11.25
# Ciudad de Mexico                No                        -58.10

# %% [markdown]
# ### Conclusions
# ##### Among the states where manufacturing employment grew the most, some are not on the border.
# ##### That is the case of Guanajuato, Queretaro, San Luis Potosi or Durango. ( Although Durango is close to the border.)
# #### Four of the six border states are above the national average. The only exceptions are Nuevo Leon and Sonora.
# #### This may indicate two possibilities:
# #### 1. The nearshoring effect is not concentrated exclusively at the border.
# #### 2. Other simultaneous phenomena may be driving manufacturing employment upward in Mexico.

# %% [markdown]
# ### Comparison with the population

# %%
# open population data
dfp = pd.read_csv("data/mexico-population-refined.csv")
dfp
# Out:
#                               State       2010       2021 Border
# 0                    Total nacional  112336538  126014024     No
# 1                    Aguascalientes    1184996    1425607     No
# 2                   Baja California    3155070    3769020    Yes
# 3               Baja California Sur     637026     798447     No
# 4                          Campeche     822441     928363     No
# 5              Coahuila de Zaragoza    2748391    3146771    Yes
# 6                            Colima     650555     731391     No
# 7                           Chiapas    4796580    5543828     No
# 8                         Chihuahua    3406465    3741869    Yes
# 9                  Ciudad de Mexico    8851080    9209944     No
# 10                          Durango    1632934    1832650     No
# 11                       Guanajuato    5486372    6166934     No
# 12                         Guerrero    3388768    3540685     No
# 13                          Hidalgo    2665018    3082841     No
# 14                          Jalisco    7350682    8348151     No
# 15                           Mexico   15175862   16992418     No
# 16              Michoacan de Ocampo    4351037    4748846     No
# 17                          Morelos    1777227    1971520     No
# 18                          Nayarit    1084979    1235456     No
# 19                       Nuevo Leon    4653458    5784442    Yes
# 20                           Oaxaca    3801962    4132148     No
# 21                           Puebla    5779829    6583278     No
# 22                        Queretaro    1827937    2368467     No
# 23                     Quintana Roo    1325578    1857985     No
# 24                  San Luis Potosi    2585518    2822255     No
# 25                          Sinaloa    2767761    3026943     No
# 26                           Sonora    2662480    2944840    Yes
# 27                          Tabasco    2238603    2402598     No
# 28                       Tamaulipas    3268554    3527735    Yes
# 29                         Tlaxcala    1169936    1342977     No
# 30  Veracruz de Ignacio de la Llave    7643194    8062579     No
# 31                          Yucatan    1955577    2320898     No
# 32                        Zacatecas    1490668    1622138     No

# %%
## merge
df_jp = pd.merge(df2, dfp,left_on = ["State", "Border"], right_on = ["State","Border"])
df_jp
# Out:
#                               State Border         2010         2021  \
# 0                    Aguascalientes     No    37,967.00    63,036.00
# 1                   Baja California    Yes   216,912.00   364,420.00
# 2                         Chihuahua    Yes   245,815.00   408,068.00
# 3                  Ciudad de Mexico     No    51,311.00    21,499.00
# 4              Coahuila de Zaragoza    Yes   165,669.00   264,349.00
# 5                           Durango     No    25,165.00    46,152.00
# 6                        Guanajuato     No    70,660.00   163,990.00
# 7                           Jalisco     No   102,031.00   156,146.00
# 8                            Mexico     No   117,900.00   138,471.00
# 9                        Nuevo Leon    Yes   218,776.00   311,784.00
# 10                           Puebla     No    71,544.00    79,592.00
# 11                        Queretaro     No    52,887.00   107,124.00
# 12                  San Luis Potosi     No    46,141.00    90,954.00
# 13                       Tamaulipas    Yes   162,298.00   258,257.00
# 14                   Total nacional     No 1,810,482.00 2,791,909.00
# 15  Veracruz de Ignacio de la Llave     No    16,303.00    21,680.00
# 16                          Yucatan     No    20,127.00    24,503.00
#
#     Jobs pct chg 2010 - 2021       2010       2021
# 0                      66.03    1184996    1425607
# 1                      68.00    3155070    3769020
# 2                      66.01    3406465    3741869
# 3                     -58.10    8851080    9209944
# 4                      59.56    2748391    3146771
# 5                      83.40    1632934    1832650
# 6                     132.08    5486372    6166934
# 7                      53.04    7350682    8348151
# 8                      17.45   15175862   16992418
# 9                      42.51    4653458    5784442
# 10                     11.25    5779829    6583278
# 11                    102.55    1827937    2368467
# 12                     97.12    2585518    2822255
# 13                     59.13    3268554    3527735
# 14                     54.21  112336538  126014024
# 15                     32.98    7643194    8062579
# 16                     21.74    1955577    2320898

# %%
dfb = df_jp.query("Border == 'Yes'")
dfb
# Out:
#                    State Border       2010       2021  \
# 1        Baja California    Yes 216,912.00 364,420.00
# 2              Chihuahua    Yes 245,815.00 408,068.00
# 4   Coahuila de Zaragoza    Yes 165,669.00 264,349.00
# 13            Tamaulipas    Yes 162,298.00 258,257.00
# 9             Nuevo Leon    Yes 218,776.00 311,784.00
#
#     Jobs pct chg 2010 - 2021     2010     2021  Population pct chg 2010 - 2021
# 1                      68.00  3155070  3769020                           19.46
# 2                      66.01  3406465  3741869                            9.85
# 4                      59.56  2748391  3146771                           14.50
# 13                     59.13  3268554  3527735                            7.93
# 9                      42.51  4653458  5784442                           24.30

# %%
dfnb = df_jp.query("Border == 'No'")
dfnb
# Out:
#                               State Border         2010         2021  \
# 6                        Guanajuato     No    70,660.00   163,990.00
# 11                        Queretaro     No    52,887.00   107,124.00
# 12                  San Luis Potosi     No    46,141.00    90,954.00
# 5                           Durango     No    25,165.00    46,152.00
# 0                    Aguascalientes     No    37,967.00    63,036.00
# 14                   Total nacional     No 1,810,482.00 2,791,909.00
# 7                           Jalisco     No   102,031.00   156,146.00
# 15  Veracruz de Ignacio de la Llave     No    16,303.00    21,680.00
# 16                          Yucatan     No    20,127.00    24,503.00
# 8                            Mexico     No   117,900.00   138,471.00
# 10                           Puebla     No    71,544.00    79,592.00
# 3                  Ciudad de Mexico     No    51,311.00    21,499.00
#
#     Jobs pct chg 2010 - 2021       2010       2021  \
# 6                     132.08    5486372    6166934
# 11                    102.55    1827937    2368467
# 12                     97.12    2585518    2822255
# 5                      83.40    1632934    1832650
# 0                      66.03    1184996    1425607
# 14                     54.21  112336538  126014024
# 7                      53.04    7350682    8348151
# 15                     32.98    7643194    8062579
# 16                     21.74    1955577    2320898
# 8                      17.45   15175862   16992418
# 10                     11.25    5779829    6583278
# 3                     -58.10    8851080    9209944
#
#     Population pct chg 2010 - 2021
# 6                            12.40
# 11                           29.57
# 12                            9.16
# 5                            12.23
# 0                            20.30
# 14                           12.18
# 7                            13.57
# 15                            5.49
# 16                           18.68
# 8                            11.97
# 10                           13.90
# 3                             4.05

# %%
import matplotlib.pyplot as plt

# Datos de las series
serie1 = dfb['Jobs pct chg 2010 - 2021']
serie2 = dfb['Population pct chg 2010 - 2021']

# Crear los índices para las barras
ind = np.arange(len(serie1))

# Configurar el tamaño de la figura
fig, ax = plt.subplots(figsize=(8, 5))

# Crear las barras para la serie 1
ax.barh(ind - 0.1, serie1, height=0.4, align='center', label='Jobs')

# Crear las barras para la serie 2
ax.barh(ind + 0.1, serie2, height=0.4, align='edge', label='Population')

# Configurar los ejes y etiquetas
ax.set_xlabel('%')
ax.set_title('Manufacturing jobs v. Population border states (2010 to 2021)')
ax.set_yticks(ind)
ax.set_yticklabels(list(dfb["State"]))

# Agregar una leyenda
ax.legend()

# Mostrar el gráfico de barras horizontal
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos de las series
serie1 = dfnb['Jobs pct chg 2010 - 2021']
serie2 = dfnb['Population pct chg 2010 - 2021']

# Crear los índices para las barras
ind = np.arange(len(serie1))

# Configurar el tamaño de la figura
fig, ax = plt.subplots(figsize=(8, 5))

# Crear las barras para la serie 1
ax.barh(ind - 0.1, serie1, height=0.4, align='center', label='Jobs')

# Crear las barras para la serie 2
ax.barh(ind + 0.1, serie2, height=0.4, align='edge', label='Population')

# Configurar los ejes y etiquetas
ax.set_xlabel('%')
ax.set_title('Manufacturing jobs v. Population non border states (2010 to 2021)')
ax.set_yticks(ind)
ax.set_yticklabels(list(dfnb["State"]))

# Agregar una leyenda
ax.legend()

# Mostrar el gráfico de barras horizontal
plt.show()

# %% [markdown]
# #### Conclusions
# ##### In most states manufacturing employment grew faster than population. The exceptions are Mexico City and Puebla.
# ##### In the border states, employment growth was considerably higher than population growth.
# ##### 1. Baja California: 68% employment growth and 19% population growth.
# ##### 2. Chihuahua: 66% employment growth and 10% population growth.
# ##### 3. Coahuila: 60% employment growth and 14% population growth
# ##### 4. Tamaulipas: 59% employment growth and 8% population growth
# ##### 5. Nuevo Leon: 42% employment growth and 24% population growth
# ##### 6. Sonora: 39% growth in employment and 11% growth in population
#
# #### This shows that there is a process of accelerated industrialization on the border. But also in the rest of the country (see above).

# %% [markdown]
# ## Wages

# %%
df3 = pd.DataFrame()
df3 = pd.pivot_table(df.query("Year == 2010 | Year == 2021") , values='Average wage', index=['State','Border'], columns='Year')
df3
# Out:
# Year                                        2010      2021
# State                           Border
# Aguascalientes                  No     14,748.68 18,225.56
# Baja California                 Yes    13,056.75 17,196.48
# Chihuahua                       Yes    10,580.19 13,828.38
# Ciudad de Mexico                No     22,707.69 23,832.28
# Coahuila de Zaragoza            Yes    13,507.36 17,075.26
# Durango                         No      7,479.49  9,464.91
# Guanajuato                      No     12,089.01 17,251.15
# Jalisco                         No     15,455.90 20,461.99
# Mexico                          No     22,604.22 20,998.42
# Nuevo Leon                      Yes    15,722.89 21,112.53
# Otras entidades federativas     No     12,702.66 16,852.90
# Puebla                          No     17,398.60 18,550.93
# Queretaro                       No     18,581.31 21,597.75
# San Luis Potosi                 No     12,885.84 19,035.93
# Sonora                          No     11,689.09 15,660.36
# Tamaulipas                      Yes    12,532.49 14,914.59
# Total nacional                  No     13,945.50 17,397.75
# Veracruz de Ignacio de la Llave No     16,712.97 26,300.53
# Yucatan                         No      8,628.96 10,288.35

# %%
df3["Wages pct chg 2010 - 2021"] = (df3[2021] / df3[2010] - 1) * 100
df3 = df3.sort_values(by= ["Wages pct chg 2010 - 2021"], ascending = False)
df3
# Out:
# Year                                        2010      2021  \
# State                           Border
# Veracruz de Ignacio de la Llave No     16,712.97 26,300.53
# San Luis Potosi                 No     12,885.84 19,035.93
# Guanajuato                      No     12,089.01 17,251.15
# Nuevo Leon                      Yes    15,722.89 21,112.53
# Sonora                          No     11,689.09 15,660.36
# Otras entidades federativas     No     12,702.66 16,852.90
# Jalisco                         No     15,455.90 20,461.99
# Baja California                 Yes    13,056.75 17,196.48
# Chihuahua                       Yes    10,580.19 13,828.38
# Durango                         No      7,479.49  9,464.91
# Coahuila de Zaragoza            Yes    13,507.36 17,075.26
# Total nacional                  No     13,945.50 17,397.75
# Aguascalientes                  No     14,748.68 18,225.56
# Yucatan                         No      8,628.96 10,288.35
# Tamaulipas                      Yes    12,532.49 14,914.59
# Queretaro                       No     18,581.31 21,597.75
# Puebla                          No     17,398.60 18,550.93
# Ciudad de Mexico                No     22,707.69 23,832.28
# Mexico                          No     22,604.22 20,998.42
#
# Year                                    Wages pct chg 2010 - 2021
# State                           Border
# Veracruz de Ignacio de la Llave No                          57.37
# San Luis Potosi                 No                          47.73
# Guanajuato                      No                          42.70
# Nuevo Leon                      Yes                         34.28
# Sonora                          No                          33.97
# Otras entidades federativas     No                          32.67
# Jalisco                         No                          32.39
# Baja California                 Yes                         31.71
# Chihuahua                       Yes                         30.70
# Durango                         No                          26.54
# Coahuila de Zaragoza            Yes                         26.41
# Total nacional                  No                          24.76
# Aguascalientes                  No                          23.57
# Yucatan                         No                          19.23
# Tamaulipas                      Yes                         19.01
# Queretaro                       No                          16.23
# Puebla                          No                           6.62
# Ciudad de Mexico                No                           4.95
# Mexico                          No                          -7.10

# %%
## merge
df4 = pd.merge(df3, dfp,left_on = ["State", "Border"], right_on = ["State","Border"])
df4
# Out:
#                               State Border      2010      2021  \
# 0   Veracruz de Ignacio de la Llave     No 16,712.97 26,300.53
# 1                   San Luis Potosi     No 12,885.84 19,035.93
# 2                        Guanajuato     No 12,089.01 17,251.15
# 3                        Nuevo Leon    Yes 15,722.89 21,112.53
# 4                           Jalisco     No 15,455.90 20,461.99
# 5                   Baja California    Yes 13,056.75 17,196.48
# 6                         Chihuahua    Yes 10,580.19 13,828.38
# 7                           Durango     No  7,479.49  9,464.91
# 8              Coahuila de Zaragoza    Yes 13,507.36 17,075.26
# 9                    Total nacional     No 13,945.50 17,397.75
# 10                   Aguascalientes     No 14,748.68 18,225.56
# 11                          Yucatan     No  8,628.96 10,288.35
# 12                       Tamaulipas    Yes 12,532.49 14,914.59
# 13                        Queretaro     No 18,581.31 21,597.75
# 14                           Puebla     No 17,398.60 18,550.93
# 15                 Ciudad de Mexico     No 22,707.69 23,832.28
# 16                           Mexico     No 22,604.22 20,998.42
#
#     Wages pct chg 2010 - 2021       2010       2021
# 0                       57.37    7643194    8062579
# 1                       47.73    2585518    2822255
# 2                       42.70    5486372    6166934
# 3                       34.28    4653458    5784442
# 4                       32.39    7350682    8348151
# 5                       31.71    3155070    3769020
# 6                       30.70    3406465    3741869
# 7                       26.54    1632934    1832650
# 8                       26.41    2748391    3146771
# 9                       24.76  112336538  126014024
# 10                      23.57    1184996    1425607
# 11                      19.23    1955577    2320898
# 12                      19.01    3268554    3527735
# 13                      16.23    1827937    2368467
# 14                       6.62    5779829    6583278
# 15                       4.95    8851080    9209944
# 16                      -7.10   15175862   16992418

# %%
# Datos de las series
serie1 = df4['Wages pct chg 2010 - 2021']

# Crear los índices para las barras
ind = np.arange(len(serie1))

# Configurar el tamaño de la figura
fig, ax = plt.subplots(figsize=(8, 5))

# Crear las barras para la serie 1
ax.barh(ind - 0.1, serie1, height=0.4, align='center', label='Wages')

# Configurar los ejes y etiquetas
ax.set_xlabel('%')
ax.set_title('Wages evolution (2010 to 2021)')
ax.set_yticks(ind)
ax.set_yticklabels(list(df4["State"]))

# Agregar una leyenda
ax.legend()

# Mostrar el gráfico de barras horizontal
plt.show()

# %% [markdown]
# ### Conclusions
# ##### Among the states where manufacturing real wages grew the most, some are not on the border.
# ##### That is the case of Veracruz, San Luis Potosi, or Guanajuato.
# #### Five of the six border states are above the national average. The only exception is Tamaulipas.
# #### This may indicate two possibilities:
# #### 1. The nearshoring effect is not concentrated exclusively at the border.
# #### 2. Other simultaneous phenomena may be driving manufacturing employment upward in Mexico.
